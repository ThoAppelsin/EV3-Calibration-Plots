# %%
using GLM, DataFrames, Plots, Distributions, HypothesisTests, StatPlots, Measures, PlotThemes

pyplot()
theme(:wong)
wong = palette(:wong)

slicedims(mat, dim) = broadcast(x -> selectdim(mat, dim, x), 1:size(mat, dim))
ivcat(mat) = slicedims(mat, 1)
# Out:
# ┌ Info: Precompiling StatPlots [60ddc479-9b66-56df-82fc-76a74619b69c]
# └ @ Base loading.jl:1186
# ivcat (generic function with 1 method)

# %% [markdown]
# # Reading the Data

# %%
fn_tabs(str) = count(x -> x == '\t', str)

file = readchomp("data.txt");
lines = split(file, "\n");
filter!(l -> length(strip(l)) > 0, lines);
indent_lines = map(l -> (fn_tabs(l), strip(l)), lines);

function hierarch(indent_lines)
    inds = findall(i_l -> i_l[1] == indent_lines[1][1], indent_lines)
    ends = [inds[2:end]; length(indent_lines) + 1]

    if length(inds) == length(indent_lines)
        return map(i_l -> map(x -> parse(Float64, x), split(i_l[2])), indent_lines)
    end

    d = Dict()
    for (i, e) in zip(inds, ends)
        d[indent_lines[i][2]] = hierarch(indent_lines[i+1:e-1])
    end

    return d
end

data = hierarch(indent_lines)
# Out:
# Dict{Any,Any} with 4 entries:
#   "Gyro"       => Array{Float64,1}[[0.0, 2.0, 4.0, 2.0, 3.0, 4.0], [45.0, 47.0,…
#   "Motor"      => Dict{Any,Any}("Rotational"=>Array{Float64,1}[[25.0, 50.0, 56.…
#   "Ultrasonic" => Array{Float64,1}[[1.0, 3.0, 3.0, 3.2, 2.8, 3.2], [2.0, 3.0, 3…
#   "Color"      => Dict{Any,Any}("Light"=>Dict{Any,Any}("Yellow"=>Array{Float64,…

# %% [markdown]
# # Sensor Calibration Plots

# %%
function linefit(data, title, xlabel, ylabel; fitrange=nothing, interno=false)
    fit_data = fitrange === nothing ? data : data[fitrange[1] .<= data[:Parameter] .<= fitrange[2], :]
    if interno
        ols = lm(@formula(Result ~ Parameter + 0), fit_data)
        intercept, slope = 0, coef(ols)[1]
    else
        ols = lm(@formula(Result ~ Parameter), fit_data)
        intercept, slope = coef(ols)
    end
    
    display(scatter(data[:Parameter], data[:Result], title=title,
        xlabel=xlabel, ylabel=ylabel, label="Data", m=(0.2, :x, 7), c=[wong[1]]))

    display(plot!(x -> intercept + slope * x, collect(extrema(data[:Parameter])),
        label="Fit: y = $(round(intercept, digits=3)) +" *
        "$(round(slope, digits=3))⋅x"))
    
    return ols
end

function meansNdevs(data, ols)
    means_devs = by(data, :Parameter, df -> DataFrame(Mean=mean(df[:Result]), Stdev=std(df[:Result])))
    means_devs[:Parameter] = broadcast(x -> repr(round(Int, x)), means_devs[:Parameter])
    for me_sd in zip(("intercept", "slope"), coef(ols), stderror(ols))
        push!(means_devs, me_sd)
    end
    means_devs
end
# Out:
# meansNdevs (generic function with 1 method)

# %% [markdown]
# ## Ultrasonic Sensor

# %%
ultrasonic_data = DataFrame(
    vcat(([row[1] measured] for row in data["Ultrasonic"] for measured in row[2:end])...), [:Parameter, :Result])

ultrasonic_ols = linefit(ultrasonic_data, "Ultrasonic", "Actual", "Sensor");
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)
# C:\Users\utkan\.julia\conda\3\lib\site-packages\matplotlib\figure.py:448: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
meansNdevs(ultrasonic_data, ultrasonic_ols)
# Out:
# 14×3 DataFrame
# │ Row │ Parameter │ Mean     │ Stdev      │
# │     │ String    │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ 1         │ 3.04     │ 0.167332   │
# │ 2   │ 2         │ 3.0      │ 0.0        │
# │ 3   │ 3         │ 3.12     │ 0.0447214  │
# │ 4   │ 4         │ 3.88     │ 0.178885   │
# │ 5   │ 5         │ 4.94     │ 0.207364   │
# │ 6   │ 10        │ 10.1     │ 0.2        │
# │ 7   │ 15        │ 15.14    │ 0.336155   │
# │ 8   │ 20        │ 20.14    │ 0.461519   │
# │ 9   │ 25        │ 25.1     │ 0.141421   │
# │ 10  │ 30        │ 30.68    │ 0.742967   │
# │ 11  │ 40        │ 41.1     │ 0.479583   │
# │ 12  │ 50        │ 50.98    │ 0.535724   │
# │ 13  │ intercept │ 0.405569 │ 0.135404   │
# │ 14  │ slope     │ 1.0066   │ 0.00586089 │

# %% [markdown]
# ## Light - Color Sensor

# %%
datacols = [:aRed, :bGreen, :cBlue, :dIntensity]

function analyzecolor(datagroup)
    color = datagroup[:PColor][1]
    
    ctg = repeat(convert(Array, datagroup[:Light]), inner = length(datacols))
    nam = repeat(map(x -> repeat(" ", 'd' - x[1]) * x[2:end] * repeat(" ", 'd' - x[1]), String.(datacols)), outer = 2)
    vals = permutedims(mean.(convert(Array, datagroup[:, datacols])), [2, 1])
    errs = permutedims(map(x -> -(x...) / -2, convert(Array, datagroup[:, datacols])), [2, 1])
    groupedbar(nam, vals, group = ctg, xlabel = "Channel", ylabel = "Percentage (%)",
        title = color, ylim = (0, 70), yerror = errs, fillalpha = 0.3, c = repeat(wong[1:2], inner = length(datacols)))
end

color_data = DataFrame(vcat(([light pcolor row' .* [1 1 1 100]]
        for (light, lightdata) in data["Color"]
            for (pcolor, pcolordata) in lightdata
                for row in pcolordata)...), vcat([:Light, :PColor], datacols))

for col in datacols
    color_data[col] = round.(Int, color_data[col])
end
color_data = by(color_data, [:Light, :PColor],
    df -> DataFrame(permutedims(colwise(x -> confint(OneSampleTTest(x)), df[datacols])), datacols))
# Out:
# 12×6 DataFrame. Omitted printing of 2 columns
# │ Row │ Light │ PColor │ aRed                │ bGreen             │
# │     │ Any   │ Any    │ Tuple…              │ Tuple…             │
# ├─────┼───────┼────────┼─────────────────────┼────────────────────┤
# │ 1   │ Light │ Yellow │ (56.1444, 60.6556)  │ (38.7583, 41.2417) │
# │ 2   │ Light │ Red    │ (39.0252, 44.1748)  │ (0.0, 0.0)         │
# │ 3   │ Light │ Green  │ (9.58107, 12.8189)  │ (35.9843, 38.8157) │
# │ 4   │ Light │ Blue   │ (0.716923, 4.48308) │ (24.1056, 43.8944) │
# │ 5   │ Light │ Pink   │ (42.1597, 46.2403)  │ (34.7199, 36.0801) │
# │ 6   │ Light │ Orange │ (49.3223, 53.4777)  │ (21.7341, 25.0659) │
# │ 7   │ Dark  │ Yellow │ (49.1611, 51.2389)  │ (31.9199, 33.2801) │
# │ 8   │ Dark  │ Red    │ (36.0368, 39.9632)  │ (0.0, 0.0)         │
# │ 9   │ Dark  │ Green  │ (8.12201, 9.87799)  │ (33.7199, 35.0801) │
# │ 10  │ Dark  │ Blue   │ (0.0, 0.0)          │ (33.122, 34.878)   │
# │ 11  │ Dark  │ Pink   │ (55.6771, 60.3229)  │ (36.9199, 38.2801) │
# │ 12  │ Dark  │ Orange │ (48.7611, 50.8389)  │ (19.9199, 21.2801) │

# %%
plot((analyzecolor(datagroup) for datagroup in groupby(color_data, :PColor))...,
    xtickfont=font(9, "Verdana", colorant"gray40"),
    titlefont=font("Verdana", colorant"gray20"),
    margin=5mm,
    size=(900,600))

# %%
for row in eachrow(color_data)
    for datacol in datacols
        row[datacol] = (mean(row[datacol]), -(row[datacol]...) / -2)
    end
end
color_data
# Out:
# 12×6 DataFrame. Omitted printing of 1 columns
# │ Row │ Light │ PColor │ aRed            │ bGreen           │ cBlue            │
# │     │ Any   │ Any    │ Tuple…          │ Tuple…           │ Tuple…           │
# ├─────┼───────┼────────┼─────────────────┼──────────────────┼──────────────────┤
# │ 1   │ Light │ Yellow │ (58.4, 2.25559) │ (40.0, 1.24166)  │ (4.4, 1.41571)   │
# │ 2   │ Light │ Red    │ (41.6, 2.57477) │ (0.0, -0.0)      │ (0.0, -0.0)      │
# │ 3   │ Light │ Green  │ (11.2, 1.61893) │ (37.4, 1.41571)  │ (6.4, 1.41571)   │
# │ 4   │ Light │ Blue   │ (2.6, 1.88308)  │ (34.0, 9.89443)  │ (22.2, 7.92139)  │
# │ 5   │ Light │ Pink   │ (44.2, 2.04026) │ (35.4, 0.680087) │ (24.2, 1.36017)  │
# │ 6   │ Light │ Orange │ (51.4, 2.0777)  │ (23.4, 1.66587)  │ (9.6, 2.0777)    │
# │ 7   │ Dark  │ Yellow │ (50.2, 1.03885) │ (32.6, 0.680087) │ (0.0, -0.0)      │
# │ 8   │ Dark  │ Red    │ (38.0, 1.96324) │ (0.0, -0.0)      │ (0.0, -0.0)      │
# │ 9   │ Dark  │ Green  │ (9.0, 0.877989) │ (34.4, 0.680087) │ (3.4, 1.41571)   │
# │ 10  │ Dark  │ Blue   │ (0.0, -0.0)     │ (34.0, 0.877989) │ (22.4, 1.11058)  │
# │ 11  │ Dark  │ Pink   │ (58.0, 2.32294) │ (37.6, 0.680087) │ (27.0, 0.877989) │
# │ 12  │ Dark  │ Orange │ (49.8, 1.03885) │ (20.6, 0.680087) │ (6.6, 0.680087)  │

# %% [markdown]
# ## Gyro Sensor

# %%
gyro_data = DataFrame(
    vcat(([row[1] measured] for row in data["Gyro"] for measured in row[2:end])...), [:Parameter, :Result])

gyro_ols = linefit(gyro_data, "Gyro", "Actual", "Sensor");
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
meansNdevs(gyro_data, gyro_ols)
# Out:
# 10×3 DataFrame
# │ Row │ Parameter │ Mean     │ Stdev      │
# │     │ String    │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ 0         │ 3.0      │ 1.0        │
# │ 2   │ 45        │ 47.6     │ 0.894427   │
# │ 3   │ 90        │ 92.0     │ 1.41421    │
# │ 4   │ 135       │ 140.4    │ 1.34164    │
# │ 5   │ 180       │ 179.8    │ 0.83666    │
# │ 6   │ 225       │ 225.6    │ 1.94936    │
# │ 7   │ 270       │ 270.6    │ 1.81659    │
# │ 8   │ 315       │ 314.4    │ 2.07364    │
# │ 9   │ intercept │ 3.55     │ 0.570678   │
# │ 10  │ slope     │ 0.988095 │ 0.00303151 │

# %% [markdown]
# # Motor Calibration Plots

# %% [markdown]
# ## Linear Motion

# %%
linear_data = DataFrame(
    vcat(([row[1] measured] for row in data["Motor"]["Linear"] for measured in row[2:end])...), [:Parameter, :Result])

linear_ols = linefit(linear_data, "Linear Motion", "Speed", "Distance", fitrange=(1, 1000), interno=true);
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
meansNdevs(linear_data, linear_ols)
# Out:
# 10×3 DataFrame
# │ Row │ Parameter │ Mean     │ Stdev      │
# │     │ String    │ Float64  │ Float64    │
# ├─────┼───────────┼──────────┼────────────┤
# │ 1   │ 100       │ 25.3     │ 0.447214   │
# │ 2   │ 200       │ 49.0     │ 0.0        │
# │ 3   │ 300       │ 72.6     │ 0.41833    │
# │ 4   │ 400       │ 97.6     │ 0.41833    │
# │ 5   │ 500       │ 120.4    │ 0.41833    │
# │ 6   │ 1000      │ 211.6    │ 2.04328    │
# │ 7   │ 1500      │ 213.5    │ 0.866025   │
# │ 8   │ 3000      │ 235.4    │ 0.547723   │
# │ 9   │ 5000      │ 312.4    │ 2.30217    │
# │ 10  │ intercept │ 0.222548 │ 0.00276714 │

# %% [markdown]
# ## Rotational Motion

# %%
rotational_data = DataFrame(
    vcat(([row[1] meas] for row in data["Motor"]["Rotational"] for meas in row[2:end])...), [:Parameter, :Result])

rotational_ols = linefit(rotational_data, "Rotational Motion", "Speed", "Angles", interno=true);
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
meansNdevs(rotational_data, rotational_ols)
# Out:
# 11×3 DataFrame
# │ Row │ Parameter │ Mean    │ Stdev      │
# │     │ String    │ Float64 │ Float64    │
# ├─────┼───────────┼─────────┼────────────┤
# │ 1   │ 25        │ 51.75   │ 2.87228    │
# │ 2   │ 50        │ 101.6   │ 0.547723   │
# │ 3   │ 75        │ 152.4   │ 0.547723   │
# │ 4   │ 100       │ 203.2   │ 0.83666    │
# │ 5   │ 125       │ 253.8   │ 1.92354    │
# │ 6   │ 150       │ 304.4   │ 1.34164    │
# │ 7   │ 200       │ 405.4   │ 0.894427   │
# │ 8   │ 250       │ 504.6   │ 3.1305     │
# │ 9   │ 300       │ 600.2   │ 3.27109    │
# │ 10  │ 350       │ 698.2   │ 3.76829    │
# │ 11  │ intercept │ 2.00917 │ 0.00254879 │
